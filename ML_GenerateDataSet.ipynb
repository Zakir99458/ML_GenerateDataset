# %%
import requests
import pandas as pd

# %%
api_key = "6d7bc7001f3b92fb5d60ea397f925a04"  # Replace with your actual API key
# url = f"https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc&api_key={api_key}"

# %%
url = f"https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1&api_key={api_key}"

# %%
url
# Out:
# 'https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1&api_key=6d7bc7001f3b92fb5d60ea397f925a04'

# %%
# Check the URL request status
response = requests.get(url)

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 172.108,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 26511},
#  {'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
# Print the data
pd.DataFrame(response.json()['results']).head(2)[['id','title','overview','popularity','release_date','vote_count']]
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
#
#                                             overview  popularity release_date  \
# 0  Imprisoned in the 1940s for the double murder ...     172.108   1994-09-23
# 1  Spanning the years 1945 to 1955, a chronicle o...     209.894   1972-03-14
#
#    vote_count
# 0       26511
# 1       20125

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','overview','popularity','release_date','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview  popularity release_date  \
# 0  Imprisoned in the 1940s for the double murder ...     172.108   1994-09-23
# 1  Spanning the years 1945 to 1955, a chronicle o...     209.894   1972-03-14
# 2  In the continuing saga of the Corleone crime f...     137.462   1974-12-20
# 3  The true story of how businessman Oskar Schind...     169.711   1993-12-15
# 4  The defense and the prosecution have rested an...      87.423   1957-04-10
#
#    vote_count
# 0       26511
# 1       20125
# 2       12144
# 3       15551
# 4        8393

# %%
df = pd.DataFrame()

# %%
for i in range(1,478):
  url = f"https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={i}&api_key={api_key}"
  response = requests.get(url)
  temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','popularity','release_date','vote_count']]
  df = pd.concat([df,temp_df],ignore_index=True)

# %%
df
# Out:
#          id                       title  \
# 0       278    The Shawshank Redemption
# 1       238               The Godfather
# 2       240       The Godfather Part II
# 3       424            Schindler's List
# 4       389                12 Angry Men
# ...     ...                         ...
# 9517  12142           Alone in the Dark
# 9518  13805              Disaster Movie
# 9519  11059           House of the Dead
# 9520  14164        Dragonball Evolution
# 9521  40016  Birdemic: Shock and Terror
#
#                                                overview  popularity  \
# 0     Imprisoned in the 1940s for the double murder ...     172.108
# 1     Spanning the years 1945 to 1955, a chronicle o...     209.894
# 2     In the continuing saga of the Corleone crime f...     137.462
# 3     The true story of how businessman Oskar Schind...     169.711
# 4     The defense and the prosecution have rested an...      87.423
# ...

# %%
df.to_csv('movies.csv')
